# %% [markdown]
# ## Exercice 1
#
# Importe le module :
#
# ```python
# import tempfile
# ```
#
# Affiche son type

# %%
import tempfile

print(type(tempfile))
# Out:
# <class 'module'>

# %% [markdown]
# ## Exercice 2
#
# Affiche l'aide du module :
#
# ```python
# help(tempfile)
# ```
#
# Observe les principales fonctions disponibles.

# %%
import tempfile

help(tempfile)

# %% [markdown]
# ## Exercice 3
#
# Parmi les éléments suivants, indique lesquels pourraient être temporaires :
#
# - fichier téléchargé avant traitement
#     - oui
# - rapport final envoyé au client
#     - non
# - cache d'une application
#     - oui
# - fichier intermédiaire de conversion PDF
#     - oui
# - base de données de production
#     - non

# %% [markdown]
# ## Exercice 4
#
# Complète le tableau :
#
# | Situation                       | Temporaire ? |
# | ------------------------------- | ------------ |
# | Fichier de test                 | oui          |
# | Rapport final                   | non          |
# | Cache                           | oui          |
# | Archive intermédiaire           | oui          |
# | Données utilisateur permanentes | non          |

# %% [markdown]
# ## Exercice 5
#
# Associe chaque besoin à l'outil approprié :
#
# | Besoin                                          | Outil                |
# | ----------------------------------------------- | -------------------- |
# | Créer un fichier temporaire                     | TemporaryFile()      |
# | Créer un dossier temporaire                     | TemporaryDirectory() |
# | Créer un fichier temporaire avec un nom visible | NamedTemporaryFile() |

# %% [markdown]
# ## Exercice 6
#
# Explique pourquoi cette approche est risquée :
#
# ```python
# Path("temp.txt")
# ```
#
# puis plus tard :
#
# ```python
# unlink()
# ```

# %% [markdown]
# Le fichier peut ne jamais être supprimé si le programme s'arrête avant d'appeler unlink().
#
# On peut également oublier de faire le nettoyage.
#
# Cela peut laisser des fichiers inutiles sur le disque.

# %% [markdown]
# ## Exercice 7
#
# Complète :
#
# ```text
# Créer
# ↓
# Utiliser
# ↓
# Supprimer automatiquement
# ```

# %% [markdown]
# ## Exercice 8
#
# Réponds avec tes propres mots :
#
# 1. Quel est le rôle du module `tempfile` ?
#     - créer et gérer des fichiers et dossiers temporaires.
# 2. Quel problème cherche-t-il à résoudre ?
#     - créer des ressources temporaires et les nettoyer automatiquement.
# 3. Pourquoi les noms générés automatiquement sont-ils utiles ?
#     - ils évitent les conflits avec des fichiers déjà existants et permettent à plusieurs programmes d'utiliser des fichiers temporaires en même temps.
# 4. Dans quel cas utiliserais-tu un fichier temporaire ?
#     - test
#     - traitement avant sauvegarde
# 5. Dans quel cas ne faudrait-il pas utiliser un fichier temporaire ?
#     - quand on a besoin de fichier plus tard
