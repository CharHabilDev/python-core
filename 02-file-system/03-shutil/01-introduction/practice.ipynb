# %% [markdown]
# ## Exercice 1
#
# Importe le module `shutil`.
#
# Affiche ensuite son type.

# %%
import shutil

print(type(shutil))
# Out:
# <class 'module'>

# %% [markdown]
# ## Exercice 2
#
# Affiche l'aide intégrée du module afin d'observer les fonctions qu'il contient.
#
# Explore la sortie sans chercher à tout comprendre.

# %%
print(help(shutil))
# Out:
# Help on module shutil:
#
# NAME
#     shutil - Utility functions for copying and archiving files and directory trees.
#
# MODULE REFERENCE
#     https://docs.python.org/3.14/library/shutil#module-shutil
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     XXX The functions here don't copy the resource fork or other metadata on Mac.
#
# CLASSES
#     builtins.OSError(builtins.Exception)
#         Error
#             SameFileError
#         SpecialFileError
#
#     class Error(builtins.OSError)
#      |  Method resolution order:
#      |      Error
#      |      builtins.OSError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
# ...

# %% [markdown]
# ## Exercice 3
#
# Parmi les opérations suivantes, indique celles qui semblent appartenir à `shutil` :
#
# - Copier un fichier
# - Obtenir le dossier courant
# - Déplacer un dossier
# - Lire une variable d'environnement
# - Créer une archive
# - Vérifier qu'un fichier existe

# %% [markdown]
# ### Résultat :
#
# - Copier un fichier
# - Déplacer un dossier
# - Créer une archive

# %% [markdown]
# ## Exercice 4
#
# Associe chaque tâche au module le plus adapté :
#
# | Tâche                                 | Module    |
# |---------------------------------------|--------   |
# | Construire un chemin                  | pathlib   |
# | Copier un fichier                     | shutil    |
# | Obtenir le dossier courant            | os        |
# | Lire une variable d'environnement     | os        |
# | Supprimer un dossier complet          | shutil    |
# | Vérifier qu'un fichier existe         | pathlib   |

# %% [markdown]
# ## Exercice 5
#
# Complète le tableau suivant :
#
# | Module  | Rôle principal                                                      |
# | ------- | --------------------------------------------------------------------|
# | pathlib | manipuler les chemins de fichiers                                   |
# | os      | interagir avec le système d'exploitation                            |
# | shutil  | effectuer des opérations de haut niveau sur les fichiers et dossiers|

# %% [markdown]
# ## Exercice 6
#
# Pour chaque situation, choisis le module le plus adapté :

# %% [markdown]
# ### Situation A
#
# Tu veux créer le chemin :
#
# ```text
# documents/cours/python/notes.txt
# ```
#
# #### Résultats :
#     `pathlib`

# %% [markdown]
# ### Situation B
#
# Tu veux connaître le dossier courant.
#
# #### Résultats :
#     `os`

# %% [markdown]
# ### Situation C
#
# Tu veux copier un projet dans un dossier de sauvegarde.
#
# #### Résultats :
#     `shutil`

# %% [markdown]
# ### Situation D
#
# Tu veux lire une variable d'environnement nommée :
#
# ```text
# API_KEY
# ```
#
# #### Résultats :
#     `os`

# %% [markdown]
# ### Situation E
#
# Tu veux supprimer un dossier contenant plusieurs sous-dossiers et fichiers.
#
# #### Résultats :
#     `shutil`

# %% [markdown]
# ## Exercice 7
#
# Réponds avec tes propres mots :
#
# 1. Quel est le rôle principal de `shutil` ?
#     - il permet d'exécuter des opérations telsque que  (copier, déplacer, archiver/zipper ou supprimer des dossiers entiers).
# 2. Pourquoi `shutil` est-il considéré comme un module de haut niveau ?
#     - parcequ'il permet d'exécuter des opérations complexes comme supprimer un dossier complet en une seule ligne de code contrairement à `os` qui a besoin des vérifications (lister le contenu du dossier principal, vérifier si c'est un fichier ou un dossier) et qui est long aussi.
# 3. Quelle différence vois-tu entre `Path` et `shutil` ?
#     - `Path` est doué avec les chemins alors que `shutil` est doué avec les opérations complexes sur les fichiers et dossiers.
# 4. Quelle différence vois-tu entre `os` et `shutil` ?
#     - `os` gère les interactions avec le système d'exploitation alors que `shutil` est spécialisé dans la manipulation de haut niveau des fichiers et des dossiers.
# 5. Dans quel cas utiliserais-tu `shutil` dans un projet réel ?
#     - créer un système de sauvegarde (exemple `base de donnée`)
#     - organisation automatique de fichiers
#     - supprimer les dossiers d'un utilisateur dans une application

# %% [markdown]
# ## Exercice 8
#
# Imagine que tu développes un script de sauvegarde automatique.
#
# Explique brièvement comment :
#
# - `pathlib`
# - `os`
# - `shutil`
#
# pourraient travailler ensemble dans ce projet.

# %% [markdown]
# #### Réponses
#
# 1. `os` récupère des informations système
#    (variables d'environnement, utilisateur, etc.)
#
# 2. `pathlib` construit et vérifie les chemins
#
# 3. `shutil` copie, déplace ou archive les données
