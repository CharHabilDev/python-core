# %% [markdown]
# ## Exercices
#
# ### Exercice 1
#
# Crée un `timedelta` représentant :
#
# ```text
# 7 jours
# ```
#
# et affiche-le.

# %%
from datetime import timedelta

days= timedelta(days=7)

print(f"{days} jours")
# Out:
# 7 days, 0:00:00 jours

# %% [markdown]
# ---
#
# ### Exercice 2
#
# Crée un `timedelta` représentant :
#
# ```text
# 2 heures
# ```
#
# et affiche-le.

# %%
from datetime import timedelta

hours = timedelta(hours=2)

print(f"{hours} heures")
# Out:
# 2:00:00 heures

# %% [markdown]
# ---
#
# ### Exercice 3
#
# Crée un `timedelta` représentant :
#
# ```text
# 30 minutes
# ```
#
# et affiche-le.

# %%
from datetime import timedelta
minutes = timedelta(minutes=30)
print(f"{minutes} minutes")
# Out:
# 0:30:00 minutes

# %% [markdown]
# ---
#
# ### Exercice 4
#
# Complète :
#
# | Argument  | Meaning     |
# | --------- | ----------- |
# | `days`    | jours       |
# | `weeks`   | semaines    |
# | `hours`   | heures      |
# | `minutes` | minutes     |
# | `seconds` | secondes    |

# %% [markdown]
# ---
#
# ### Exercice 5
#
# Associe :
#
# | Duration   | Argument |
# | ---------- | -------- |
# | 10 days    | `days`          |
# | 3 weeks    | `weeks`         |
# | 2 hours    | `hours`         |
# | 45 minutes | `minutes`         |

# %% [markdown]
# ---
#
# ### Exercice 6
#
# Complète :
#
# ```text
# timedelta()
#
# ↓
#
# days
# weeks
# hours
# minutes
# seconds
#
# ↓
#
# durée
# ```

# %% [markdown]
# ---
#
# ### Exercice 7
#
# Parmi les situations suivantes, quel argument utiliserais-tu principalement ?
#
# - Une semaine d'essai : `weeks`
# - Une réunion de 2 heures : `hours`
# - Une pause de 15 minutes : `minutes`
# - Une expiration après 30 secondes : `seconds`
# - Un délai de 90 jours : `days`

# %% [markdown]
# ---
#
# ### Exercice 8
#
# Réponds avec tes propres mots :
#
# 1. Comment crée-t-on un objet `timedelta` ?
#     - on crée un objet `timedelta` en utilisant des arguments comme `days`, `weeks`, `hours`, `minutes` ou `seconds`.
# 2. Quel argument utiliserais-tu pour représenter une semaine ?
#     - `weeks`
# 3. Pourquoi Python propose-t-il plusieurs unités de temps ?
#     - meilleure précision ;
#     - meilleure lisibilité ;
#     - moins de risques d'erreurs
# 4. Quelle différence existe entre `days` et `weeks` ?
#     - 7 days = 1 week
# 5. Cite un cas réel où tu utiliserais plusieurs arguments en même temps
#     - estimation d'une heure d'arrivé
