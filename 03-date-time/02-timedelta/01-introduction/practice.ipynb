# %% [markdown]
# # Exercises
#
# ## Exercice 1
#
# Import:
#
# ```python
# timedelta
# ```
#
# from the `datetime` module.
#
# Display it.

# %%
from datetime import timedelta
print(timedelta)
# Out:
# <class 'datetime.timedelta'>

# %% [markdown]
# ---
#
# ## Exercice 2
#
# Display:
#
# ```python
# type(timedelta)
# ```

# %%
from datetime import timedelta
print(type(timedelta))
# Out:
# <class 'type'>

# %% [markdown]
# ---
#
# ## Exercice 3
#
# Display the help page:
#
# ```python
# help(timedelta)
# ```

# %%
from datetime import timedelta
help(timedelta)

# %% [markdown]
# ---
#
# ## Exercice 4
#
# Complète :
#
# | Object      | Represents            |
# | ----------- | --------------------- |
# | `date`      | une date              |
# | `time`      | une heure             |
# | `datetime`  | une date et une heure |
# | `timedelta` | une durée             |

# %% [markdown]
# ---
#
# ## Exercice 5
#
# Parmi les situations suivantes, lesquelles représentent une durée ?
#
# - 7 days : `oui`
# - Birthday : `non`
# - 2 hours : `oui`
# - Subscription period : `oui`
# - Current date : `non`

# %% [markdown]
# ---
#
# ## Exercice 6
#
# Complète :
#
# ```text
# timedelta
#
# ↓
#
# period of time
#
# ↓
#
# duration
# ```

# %% [markdown]
# ---
#
# ## Exercice 7
#
# Associe :
#
# | Situation           | Object      |
# | ------------------- | ----------- |
# | Current date        | `date`      |
# | Meeting duration    | `timedelta` |
# | Birthday            | `date`      |
# | Subscription period | `timedelta` |

# %% [markdown]
# ---
#
# ## Exercice 8
#
# Réponds avec tes propres mots :
#
# 1. Quel est le rôle de `timedelta` ?
#     - c'est de représenter une durée entre deux dates ou deux heures
# 2. Quelle différence existe entre `datetime` et `timedelta` ?
#     - `datetime` représente un moment précis alors `timedelta` est une durée
# 3. Cite deux exemples de durées.
#     - délai d'expiration
#     - période d'essai
# 4. Pourquoi les applications utilisent-elles des durées ?
#     - pour calculer des échéances, des expirations, des délais ou des périodes d'attente.
# 5. Dans quel projet pourrais-tu utiliser `timedelta` ?
#     - système de réservation
#     - gestion d'abonnements
#     - gestionnaire de tâches avec échéances
#     - application de livraison
