# %% [markdown]
# ## Exercice 1
#
# Affiche la date et l'heure actuelles.
#
# ---

# %%
from datetime import datetime
print(datetime.now())
# Out:
# 2026-08-31 14:31:52.030583

# %% [markdown]
# ## Exercice 2
#
# Stocke la date et l'heure actuelles dans une variable puis affiche-la.
#
# ---

# %%
from datetime import datetime

current_datetime = datetime.now()

print(current_datetime)
# Out:
# 2026-08-31 14:32:56.419104

# %% [markdown]
# ## Exercice 3
#
# Teste la méthode `datetime.today()`.
#
# Observe le résultat obtenu.
#
# ---

# %%
from datetime import datetime

print(datetime.today())
# Out:
# 2026-08-31 14:33:57.452212

# %% [markdown]
# ## Exercice 4
#
# Complète :
#
# | Méthode            | Rôle                                          |
# | ------------------ | --------------------------------------------- |
# | `datetime.now()`   | retourne la date et l'heure actuelles         |
# | `datetime.today()` | retourne la date et l'heure actuelles du jour |
#
#
# ---

# %% [markdown]
# ## Exercice 5
#
# Associe :
#
# | Besoin                        | Méthode |
# | ----------------------------- | ------- |
# | Date et heure actuelles       |`datetime.now()`        |
# | Horodatage d'un log           |`datetime.now()`      |
# | Date de création d'un rapport |`datetime.now()`        |
#
# ---

# %% [markdown]
# ## Exercice 6
#
# Complète :
#
# ```text
# datetime.now()
#
# ↓
#
# objet datetime
#
# ↓
#
# date et heure actuelles
# ```
#
# ---

# %% [markdown]
# ## Exercice 7
#
# Parmi les situations suivantes, lesquelles pourraient utiliser `datetime.now()` ?
#
# - Sauvegarde automatique : oui
# - Horodatage d'un message : oui
# - Calculatrice simple : non (sans historique)
# - Journal d'événements (log) : oui
# - Génération d'un reçu : oui (si date dedans)
#
# ---

# %% [markdown]
# ## Exercice 8
#
# Réponds avec tes propres mots :
#
# 1. À quoi sert `datetime.now()` ?
#     - récupérer la date et l'heure exactes du moment présent.
# 2. Que retourne cette méthode ?
#     - un objet `datetime` contenant la date et l'heure actuelles
# 3. Pourquoi stocker le résultat dans une variable ?
#     - pour la manipuler plus tard
# 4. Dans quel type d'application utiliserais-tu cette méthode ?
#     - générateur de logs
#     - paiement
#     - streaming
# 5. Quelle différence as-tu observée entre `datetime.now()` et `datetime.today()` ?
