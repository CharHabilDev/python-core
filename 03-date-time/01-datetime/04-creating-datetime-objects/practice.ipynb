# %% [markdown]
# ## Exercice 1
#
# Create a `datetime` representing:
#
# ```text
# 2026-01-01
# ```
#
# Display the object.

# %%
from datetime import datetime

print(datetime(2026, 1, 1))
# Out:
# 2026-01-01 00:00:00

# %% [markdown]
# ---
#
# ## Exercice 2
#
# Create a `datetime` representing:
#
# ```text
# 2030-12-31 23:59:59
# ```
#
# Display the object.

# %%
from datetime import datetime

print(datetime(2030, 1, 1, 23, 59, 59))
# Out:
# 2030-01-01 23:59:59

# %% [markdown]
# ---
#
# ## Exercice 3
#
# Create a `datetime` representing your birth date.
#
# The time component is optional.

# %%
from datetime import datetime

birth_date = datetime(2007, 7, 2)

print(birth_date)
# Out:
# 2007-07-02 00:00:00

# %% [markdown]
# ---
#
# ## Exercice 4
#
# Complète :
#
# | Argument | Description |
# | -------- | ----------- |
# | year     |l'année             |
# | month    |le mois             |
# | day      |le jour             |
# | hour     |l'heure             |
# | minute   |la minute             |
# | second   |la seconde             |

# %% [markdown]
# ---
#
# ## Exercice 5
#
# Associe :
#
# | Situation               | Datetime personnalisé ? |
# | ----------------------- | ----------------------- |
# | Anniversaire            |oui                         |
# | Date actuelle           |non                         |
# | Date limite d'un projet |oui                         |
# | Rendez-vous futur       |oui                         |

# %% [markdown]
# ---
#
# ## Exercice 6
#
# Complète :
#
# ```text
# datetime()
#
# ↓
#
# year
# month
# day
#
# ↓
#
# datetime object
# ```

# %% [markdown]
# ---
#
# ## Exercice 7
#
# Parmi les situations suivantes, lesquelles nécessitent la création d'un `datetime` personnalisé ?
#
# - Date de naissance : oui
# - Date actuelle du système : non
# - Réservation d'hôtel : oui
# - Échéance d'un abonnement : oui
# - Heure d'un rendez-vous : oui

# %% [markdown]
# ---
#
# ## Exercice 8
#
# Réponds avec tes propres mots :
#
# 1. Pourquoi créer un `datetime` manuellement ?
#     - pour représenter une date passée ou future qui ne correspond pas à la date actuelle du système.
# 2. Quels paramètres sont obligatoires ?
#     - l'année, le mois et le jour
# 3. Quels paramètres sont optionnels ?
#     - l'hour, minute, second et microsecond.
# 4. Quelle différence existe entre `datetime.now()` et `datetime(...)` ?
#     - `datetime.now()` represente la date actuelle alors que `datetime(...)` represente une date voulue
# 5. Cite un cas réel où tu utiliserais un `datetime` personnalisé.
#     - planifier un évenement
