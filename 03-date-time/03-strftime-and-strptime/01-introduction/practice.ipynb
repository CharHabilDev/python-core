# %% [markdown]
# # Exercices
#
# ### Exercice 1
#
# ```python
# from datetime import datetime
#
# print(datetime.strftime)
# ```

# %%
from datetime import datetime

print(datetime.strftime)
# Out:
# <method 'strftime' of 'datetime.date' objects>

# %% [markdown]
# ---
#
# ### Exercice 2
#
# ```python
# from datetime import datetime
#
# print(datetime.strptime)
# ```

# %%
from datetime import datetime

print(datetime.strptime)
# Out:
# <built-in method strptime of type object at 0xaab120>

# %% [markdown]
# ---
#
# ### Exercice 3
#
# ```python
# from datetime import datetime
#
# help(datetime.strftime)
# ```
#
# Puis :
#
# ```python
# help(datetime.strptime)
# ```

# %%
from datetime import datetime

print("strftime help")
help(datetime.strftime()()()()()()()())

print("strptime help")
help(datetime.strptime)
# Out:
# strftime help
# Help on method descriptor strftime:
#
# strftime(...) unbound datetime.date method
#     format -> strftime() style string.
#
# strptime help
# Help on built-in function strptime:
#
# strptime(...) class method of datetime.datetime
#     string, format -> new datetime parsed from a string (like time.strptime()).

# %% [markdown]
# ---
#
# ### Exercice 4
#
# Complète :
#
# | Fonction     | Conversion |
# | ------------ | ---------- |
# | `strftime()` |date/datetime to string            |
# | `strptime()` |string to datetime            |

# %% [markdown]
# ---
#
# ### Exercice 5
#
# Associe :
#
# | Situation                            | Outil |
# | ------------------------------------ | ----- |
# | Afficher une date à un utilisateur   |`strftime`       |
# | Lire une date saisie au clavier      |`strptime`       |
# | Générer un rapport lisible           |`strftime`       |
# | Convertir une date texte en datetime |`strptime`       |

# %% [markdown]
# ---
#
# ### Exercice 6
#
# Complète :
#
# ```text
# datetime
#
# ↓
#
# strftime()
#
# ↓
#
# texte
# ```
#
# et
#
# ```text
# texte
#
# ↓
#
# strptime()
#
# ↓
#
# datetime
# ```

# %% [markdown]
# ---
#
# ### Exercice 7
#
# Parmi les situations suivantes, quel outil utiliserais-tu principalement ?
#
# - Affichage d'une date dans une interface : `strftime()`
# - Lecture d'une date depuis un formulaire : `strptime()`
# - Génération d'un reçu : `strftime()`
# - Import d'un fichier CSV contenant des dates : `strptime()`
# - Affichage d'un historique : `strptime()`

# %% [markdown]
# ---
#
# ### Exercice 8
#
# Réponds avec tes propres mots :
#
# 1. Quel est le rôle de `strftime()` ?
#     - convertir un objet datetime en string
# 2. Quel est le rôle de `strptime()` ?
#     - convertir un string en objet datetime
# 3. Pourquoi les applications manipulent-elles souvent des dates sous forme de texte ?
#     - stockage / échange de données
#     - affichage adapté à l'utilisateur
# 4. Quelle différence existe entre un objet `datetime` et une chaîne de caractères ?
#     - Un datetime sait faire des calculs de dates, comparaisons, additions de durées, etc.
# 5. Cite un exemple réel où tu utiliserais les deux fonctions ensemble.
#     - saise utilisateur --+ convertion pour le manipuler ou le stocker
