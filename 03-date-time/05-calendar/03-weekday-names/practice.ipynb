# %% [markdown]
# # Exercises
#
# ### Exercice 1
#
# Import `calendar` and display:
#
# ```python
# calendar.day_name
# ```

# %%
import calendar

for day in calendar.day_name:
    print(day)
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %% [markdown]
# ---
#
# ### Exercice 2
#
# Display:
#
# ```python
# calendar.day_name[0]
# ```

# %%
import calendar

print(calendar.day_name[0])
# Out:
# Monday

# %% [markdown]
# ---
#
# ### Exercice 3
#
# Display:
#
# ```python
# calendar.day_name[6]
# ```

# %%
import calendar

print(calendar.day_name[6])
# Out:
# Sunday

# %% [markdown]
# ---
#
# ### Exercice 4
#
# Complète :
#
# | Element             | Role                   |
# | ------------------- | ---------------------- |
# | `calendar.day_name` | contains weekday names |
# | `0`                 | Monday                 |
# | `6`                 | Sunday                 |
#
# ---
#
# ### Exercice 5
#
# Associe :
#
# | Number | Day |
# | ------ | --- |
# | `0`    |Monday     |
# | `2`    |Wednesday     |
# | `4`    |Friday     |
# | `6`    |Sunday     |
#
# ---
#
# ### Exercice 6
#
# Complète :
#
# ```text
# calendar.day_name[0]
#
# ↓
#
# Monday
# ```
#
# et
#
# ```text
# calendar.day_name[6]
#
# ↓
#
# Sunday
# ```
#
# ---
#
# ### Exercice 7
#
# Parmi les situations suivantes, lesquelles pourraient utiliser weekday names ?
#
# * School timetable : oui
# * Booking system : oui
# * Calculator : non
# * Weekly planner : oui
# * Work schedule : oui
#
# ---
#
# ### Exercice 8
#
# Réponds avec tes propres mots :
#
# 1. Quel est le rôle de `calendar.day_name` ?
#     - `calendar.day_name` permet d'obtenir les noms des jours de la semaine
# 2. Pourquoi les jours possèdent-ils des numéros ?
#     - les numéros permettent de manipuler, comparer et stocker les jours plus facilement dans les programmes
# 3. Quelle différence existe entre `calendar.month()` et `calendar.day_name` ?
#     - `calendar.month()` affiche un calendrier mensuel complet tandis que `calendar.day_name` fournit les noms des jours de la semaine
# 4. Cite deux applications pouvant utiliser les noms des jours.
#     - planning de travail
#     - emploi du temps scolaire
# 5. Quel projet personnel pourrait utiliser les noms des jours ?
#     - gestionnaire de tâches
