# %% [markdown]
# # Exercises
#
# ### Exercice 1
#
# Import `calendar` and display:
#
# ```python
# calendar.monthrange(2026, 1)
# ```

# %%
import calendar
print(calendar.monthrange(2026, 1))
# Out:
# (calendar.THURSDAY, 31)

# %% [markdown]
# ---
#
# ### Exercice 2
#
# Display:
#
# ```python
# calendar.monthrange(2026, 2)
# ```

# %%
import calendar
print(calendar.monthrange(2026, 2))
# Out:
# (calendar.SUNDAY, 28)

# %% [markdown]
# ---
#
# ### Exercice 3
#
# Display:
#
# ```python
# calendar.isleap(2024)
# ```
#
# and
#
# ```python
# calendar.isleap(2025)
# ```

# %%
import calendar

print("2024 is leap ?" , calendar.isleap(2024))
print("2025 is leap ?" , calendar.isleap(2025))
# Out:
# 2024 is leap ? True
# 2025 is leap ? False

# %% [markdown]
# ---
#
# ### Exercice 4
#
# Complète :
#
# | Function       | Role |
# | -------------- | ---- |
# | `monthrange()` |retourne (`weekday`, `days_in_month`)      |
# | `isleap()`     |retourne `True` si l'année est bissextile, sinon `False`      |
#
# ---
#
# ### Exercice 5
#
# Associe :
#
# | Need                 | Function |
# | -------------------- | -------- |
# | Days in a month      |`monthrange`          |
# | Check a leap year    |`isleap`          |
# | February length      |`monthrange`          |
# | Leap year validation |`isleap`          |
#
# ---
#
# ### Exercice 6
#
# Complète :
#
# ```text
# monthrange()
#
# ↓
#
# weekday + days in month
# ```
#
# et
#
# ```text
# isleap()
#
# ↓
#
# True / False
# ```
#
# ---
#
# ### Exercice 7
#
# Parmi les situations suivantes, lesquelles pourraient utiliser ces utilities ?
#
# * Booking system : `oui`
# * Subscription management : `oui`
# * Calculator : `non`
# * School calendar : `oui`
# * Holiday planning : `oui`
#
# ---
#
# ### Exercice 8
#
# Réponds avec tes propres mots :
#
# 1. Quel est le rôle de `monthrange()` ?
#     - retourner le premier jour de la semaine d'un mois ainsi que le nombre de jours de ce mois
# 2. Quel est le rôle de `isleap()` ?
#     - vérifier si une année est bissextile
# 3. Pourquoi le nombre de jours d'un mois est-il utile ?
#     - calculer une échéance
#     - vérifier qu'une date est valide
# 4. Pourquoi les années bissextiles sont-elles importantes ?
#     - février peut avoir 29 jours
#     - certaines dates existent uniquement les années bissextiles
# 5. Quel projet personnel pourrait utiliser ces fonctions ?
#     - gestionnaire de tâches
