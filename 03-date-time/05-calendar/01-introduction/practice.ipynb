# %% [markdown]
# # Exercises
#
# ### Exercice 1
#
# Import the module:
#
# ```python
# import calendar
# ```
#
# Display the module.

# %%
import calendar

print(calendar)
# Out:
# <module 'calendar' from '/usr/lib/python3.14/calendar.py'>

# %% [markdown]
# ---
#
# ### Exercice 2
#
# Display the type of:
#
# ```python
# calendar
# ```

# %%
import calendar

print(type(calendar))
# Out:
# <class 'module'>

# %% [markdown]
# ---
#
# ### Exercice 3
#
# Use:
#
# ```python
# help(calendar)
# ```
#
# Observe the available functions.

# %%
import calendar
print(help(calendar))
# Out:
# Help on module calendar:
#
# NAME
#     calendar - Calendar printing functions
#
# MODULE REFERENCE
#     https://docs.python.org/3.14/library/calendar#module-calendar
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     Note when comparing these calendars to the ones printed by cal(1): By
#     default, these calendars have Monday as the first day of the week, and
#     Sunday as the last (the European convention). Use setfirstweekday() to
#     set the first day of the week (0=Monday, 6=Sunday).
#
# CLASSES
#     builtins.IndexError(builtins.LookupError)
#         IllegalMonthError(builtins.ValueError, builtins.IndexError)
#     builtins.ValueError(builtins.Exception)
# ...

# %% [markdown]
# ---
#
# ### Exercice 4
#
# Complète :
#
# | Module      | Purpose                                                  |
# | ----------- | -------------------------------------------------------- |
# | `calendar`  | travailler avec les calendriers, mois, semaines et jours |
# | `datetime`  | représenter des dates et des heures                      |
# | `timedelta` | représenter des durées                                   |
#
# ---
#
# ### Exercice 5
#
# Associe :
#
# | Need                      | Module |
# | ------------------------- | ------ |
# | Work with months          |`calendar`        |
# | Work with dates and times |`datetime`        |
# | Work with durations       |`timedelta`        |
#
# ---
#
# ### Exercice 6
#
# Complète :
#
# ```text
# calendar
#
# ↓
#
# months
# weeks
# days
# ```
#
# ---
#
# ### Exercice 7
#
# Parmi les situations suivantes, lesquelles pourraient utiliser le module `calendar` ?
#
# -  School timetable : `oui`
# -  Event planning : `oui`
# -  Calculator : `non`
# -  Booking system : `oui`
# -  Holiday schedule : `oui`
#
# ---
#
# ### Exercice 8
#
# Réponds avec tes propres mots :
#
# 1. Quel est le rôle du module `calendar` ?
#     - afficher une année, un mois
#     - compter les jours d'un mois
#     - afficher des calendriers mensuels ou annuels
# 2. Quelle différence existe entre `calendar` et `datetime` ?
#     - `datetime` travaille avec des instants précis
#     - `calendar` travaille avec l'organisation des jours, semaines, mois et années
# 3. Pourquoi une application pourrait-elle utiliser un calendrier ?
#     - emplois du temps
#     - événements
# 4. Cite deux exemples d'applications utilisant un calendrier.
#     - agenda scolaire
#     - application de gestion de rendez-vous
# 5. Quel projet personnel pourrait utiliser le module `calendar` ?
#     - gestionnaire de tâches
