# %% [markdown]
# # Exercices
#
# ## Exercice 1
#
# Importe `Counter`.
#
# ```python
# ...
# ```

# %%
from collections import Counter

# %% [markdown]
# ---
#
# ## Exercice 2
#
# Crée un Counter à partir de :
#
# ```python
# ["apple", "banana", "apple"]
# ```

# %%
from collections import Counter

words = ["apple", "banana", "apple"]

counter = Counter(words)
print(counter)
# Out:
# Counter({'apple': 2, 'banana': 1})

# %% [markdown]
# ---
#
# ## Exercice 3
#
# Crée un Counter à partir de :
#
# ```python
# "hello"
# ```

# %%
from collections import Counter
print(Counter('hello'))
# Out:
# Counter({'l': 2, 'h': 1, 'e': 1, 'o': 1})

# %% [markdown]
# ---
#
# ## Exercice 4
#
# Complète :
#
# | Source               | Peut être utilisée avec Counter ? |
# | -------------------- | --------------------------------- |
# | Liste                | `oui`                                 |
# | Chaîne de caractères | `oui`                                 |
# | Tuple                | `oui`                                 |
# | Nombre entier        | `non`                                 |

# %% [markdown]
# ---
#
# ## Exercice 5
#
# Associe :
#
# | Donnée            | Élément compté       |
# | ----------------- | -------------------- |
# | `"banana"`        | caractères           |
# | `["a", "b", "a"]` | éléments de la liste |
# | `("red", "blue")` | éléments du tuple    |

# %% [markdown]
# ---
#
# ## Exercice 6
#
# Complète :
#
# ```text
# Liste
#
# ↓
#
# Counter
#
# ↓
#
# occurrences des éléments
# ```
#
# et
#
# ```text
# Chaîne
#
# ↓
#
# Counter
#
# ↓
#
# occurrences des caractères
# ```

# %% [markdown]
# ---
#
# ## Exercice 7
#
# Parmi les situations suivantes, lesquelles pourraient créer un Counter ?
#
# - Analyse de texte : `oui`
# - Comptage de votes : `oui`
# - Calendrier : `non`
# - Analyse de logs : `oui`
# - Statistiques de catégories : `oui`

# %% [markdown]
# ---
#
# ## Exercice 8
#
# Réponds avec tes propres mots :
#
# 1. À partir de quels types de données peut-on créer un Counter ?
#     - une liste,
#     - un dictionnaire,
#     - une chaine de caractères,
#     - un tuple
# 2. Que se passe-t-il lors de la création d'un Counter ?
#     - chaque élément est analysé puis son nombre d'occurrences est enregistré
# 3. Pourquoi une chaîne de caractères peut-elle être utilisée avec Counter ?
#     - une chaîne est un itérable de caractères
# 4. Cite deux exemples réels de création d'un Counter.
#     - - analyse de logs
#     - comptage de votes
# 5. Dans quel projet personnel pourrais-tu créer un Counter ?
#     - analyse de texte
